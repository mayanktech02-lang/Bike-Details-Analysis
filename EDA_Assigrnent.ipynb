# %% [markdown]
# # EDA - 1 Title: Bike Details Dataset
#
# ### The dataset provided focuses on used bikes, capturing various attributes to analyze the second-hand bike
# ### market. This dataset helps understand factors influencing resale prices, usage patterns, and market trends for
# ### used bikes.

# %% [markdown]
# ## Source:
# #### The dataset is available on Kaggle, simulating data commonly observed in real-world online bike resale platforms.
#
# ### Description:
# #### The dataset comprises 1061 records of used bike listings. These records include details about the bike's brand and model, selling price, kilometers driven, ownership history, and other attributes. It is particularly useful for resale value prediction, market analysis, and understanding buyer preferences.
# #### The dataset consists of 7 features, combining both numeric and categorical data, offering a comprehensive view of the second-hand bike market.
#
# #### Title: Bike Details Dataset
# * name: Brand and model name of the bike (Categorical, e.g., "Royal Enfield Classic 350", "Honda Dio")Z
# * selling_price: Listed selling price in INR (Numeric, e.g., 175000, 45000)Z
# * year: Manufacturing year of the bike (Numeric, e.g., 2019, 2015)Z
# * seller_type: Seller category, either "Individual" or "Dealer" (Categorical)Z
# * owner: Ownership history, e.g., "1st owner", "2nd owner" (Categorical)Z
# * km_driven: Total kilometers driven (Numeric, in km, e.g., 12000, 23000)Z
# * ex_showroom_price: Original showroom price in INR (Numeric, e.g., 148114.0, 89643.0, etc,.).

# %%
# Import Some Libraries for analysis of data


import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BIKE DETAILS.csv')

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.tail()
# Out:
#                     name  selling_price  year seller_type      owner  \
# 1056           Activa 3g          17000  2010  Individual  1st owner
# 1057    Honda CB twister          16000  2012  Individual  1st owner
# 1058  Bajaj Discover 125          15000  2013  Individual  2nd owner
# 1059      Honda CB Shine          12000  2009  Individual  1st owner
# 1060    Bajaj Pulsar 150          10000  2008  Individual  1st owner
#
#       km_driven  ex_showroom_price
# 1056     500000            52000.0
# 1057      33000            51000.0
# 1058      35000            57000.0
# 1059      53000            58000.0
# 1060      92233            75000.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1055 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1055 non-null   str
#  1   selling_price      1055 non-null   int64
#  2   year               1055 non-null   int64
#  3   seller_type        1055 non-null   str
#  4   owner              1055 non-null   str
#  5   km_driven          1055 non-null   int64
#  6   ex_showroom_price  622 non-null    float64
# dtypes: float64(1), int64(3), str(3)
# memory usage: 65.9 KB

# %%
df.describe()
# Out:
#        selling_price         year      km_driven  ex_showroom_price
# count    1055.000000  1055.000000    1055.000000       6.220000e+02
# mean    59713.818957  2013.871090   34295.628436       8.806079e+04
# std     56414.384170     4.305734   51708.286608       7.772528e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       8.703150e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %%
# What is the range of selling prices in the dataset?
df['Range'] = df.selling_price.max() - df.selling_price.min()

# %%
df.selling_price.max()
# Out:
# np.int64(760000)

# %% [markdown]
# # What is the range of selling prices in the dataset?

# %%
plt.figure()
sns.histplot(data= df, x= 'selling_price')
plt.title('Selling Price dispersion')
plt.show()

# %% [markdown]
# ### we are see their are some outlier of price, but most of the bikes price are belong to 5000 to 200000 range.

# %%
q1, q2, q3 = df.selling_price.quantile([0.25, .5, .75])

# %%
df['range'] = q3 -q1

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price   Range    range
# ...

# %% [markdown]
# # What is the median selling price for bikes in the dataset?

# %%
meadian_Bike = df.selling_price.median()
meadian_Bike
# Out:
# np.float64(45000.0)

# %%
# What is the most common seller type
df.seller_type.unique()
sns.countplot(df, x= 'seller_type', )
plt.title('dealer type')
plt.show()

# %% [markdown]
# ### in that figure see the most common dealer is individual

# %% [markdown]
# # 4. How many bikes have driven more than 50,000 kilometers?

# %%
count = df[df['km_driven'] > 50000].shape[0]
print('driven more than 50,000 kilometers bikes-', count)
# Out:
# driven more than 50,000 kilometers bikes- 168

# %%
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %% [markdown]
# # 5. What is the average km_driven value for each ownership type?

# %%
df1 = df[['owner', 'km_driven']]
df1.groupby('owner').mean()
# Out:
#                km_driven
# owner
# 1st owner   32732.710240
# 2nd owner   39288.991870
# 3rd owner   33292.181818
# 4th owner  311500.000000

# %% [markdown]
# # 6. What proportion of bikes are from the year 2015 or older

# %%
# Count bikes from 2015 or older
older_bikes = df[df['year'] <= 2015].shape[0]

# Total bikes
total_bikes = df.shape[0]

# Proportion
proportion = older_bikes / total_bikes

print(proportion * 100)
# Out:
# 56.58767772511848

# %% [markdown]
# # 7. What is the trend of missing values across the datasetD

# %%
missing_counts = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing_Count': missing_counts,
    'Missing %': missing_percent
}).sort_values(by='Missing %', ascending=False)

print(missing_df)
# Out:
#                    Missing_Count  Missing %
# ex_showroom_price            433  41.042654
# selling_price                  0   0.000000
# name                           0   0.000000
# year                           0   0.000000
# seller_type                    0   0.000000
# owner                          0   0.000000
# km_driven                      0   0.000000

# %%
import matplotlib.pyplot as plt

missing_percent.sort_values(ascending=False).plot(kind='bar')
plt.ylabel('Missing Percentage')
plt.title('Missing Values Trend Across Columns')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 8. What is the highest ex_showroom_price recorded, and for which bike

# %%
max_price = df['ex_showroom_price'].max()

df[df['ex_showroom_price'] == max_price][['name', 'ex_showroom_price']]
# Out:
#                            name  ex_showroom_price
# 134  Harley-Davidson Street Bob          1278000.0

# %% [markdown]
# # 9 What is the total number of bikes listed by each seller type

# %%
df['seller_type'].value_counts().reset_index()
# Out:
#   seller_type  count
# 0  Individual   1049
# 1      Dealer      6

# %% [markdown]
# # 10. What is the relationship between selling_price and km_driven for first-owner bikesD

# %%
first_owner = df[df['owner'] == '1st owner']

first_owner[['selling_price', 'km_driven']].corr()
# Out:
#                selling_price  km_driven
# selling_price       1.000000  -0.242205
# km_driven          -0.242205   1.000000

# %%
plt.figure(figsize=(8,5))
plt.scatter(first_owner['selling_price'],first_owner['km_driven'] )
plt.xlabel('selling_price')
plt.ylabel('km_driven')
plt.title('selling_price vs km_driven relation')
plt.show()

# %% [markdown]
# ### As km_driven increases, selling_price decreases.

# %% [markdown]
# # 11. Identify and remove outliers in the km_driven column using the IQR methodB

# %%
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)

IQR = Q3 - Q1
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

outliers = df[(df['km_driven'] < lower_limit) |
              (df['km_driven'] > upper_limit)]

print(outliers)
# Out:
#                                  name  selling_price  year seller_type  \
# 91           Honda Activa [2000-2015]          22989  2012  Individual
# 93                      Suzuki GS150R          30000  2010  Individual
# 115           Hero Honda Passion Plus           7500  2004  Individual
# 135            Hero Honda CBZ extreme          20000  2007  Individual
# 154                Hero Xtreme Sports          22000  2014  Individual
# 184              Honda CB Unicorn 160          75000  2015  Individual
# 363                Hero Honda CD100SS          10000  1997  Individual
# 470          Honda Activa [2000-2015]          23000  2009  Individual
# 474     Hero Honda Passion PRO [2012]          12000  2012  Individual
# 477          Honda Activa [2000-2015]          25000  2009  Individual
# 511                Hero Splendor Plus          12000  2007  Individual
# 535              Hero Honda CD Deluxe          12000  2007  Individual
# ...

# %%
# remove the outlier
df_clean = df[(df['km_driven'] >= lower_limit) &
              (df['km_driven'] <= upper_limit)]

print(df_clean.shape)
# Out:
# (1017, 7)

# %%
df_clean
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1054                     Hero  CBZ Xtreme          20000  2010  Individual
# 1055                        Bajaj  ct 100          18000  2017  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
sns.displot(df_clean['km_driven'] )

# %% [markdown]
# # 12 Perform a bivariate analysis to visualize the relationship between year and selling_priceB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

sns.scatterplot(x='year',
                y='selling_price',
                data=df)

plt.title('Relationship between Year and Selling Price')

plt.show()

# %% [markdown]
# # 13 What is the average depreciation in selling price based on the bike's age current year - manufacturing year

# %%
df['age'] = 2026 - df['year']
depreciation = df.groupby('age')['selling_price'].mean().reset_index()

print(depreciation)
# Out:
#     age  selling_price
# 0     6  183333.333333
# 1     7  119689.511628
# 2     8   87603.915385
# 3     9   78962.121212
# 4    10   58469.018692
# 5    11   56500.000000
# 6    12   48668.131868
# 7    13   51152.777778
# 8    14   35976.637681
# 9    15   35655.721311
# 10   16   31993.220339
# 11   17   22240.740741
# 12   18   34289.285714
# 13   19   24927.586207
# 14   20   23380.000000
# 15   21   16978.571429
# 16   22   15100.000000
# 17   23    8000.000000
# 18   24   20666.666667
# 19   25   40000.000000
# 20   26   20833.333333
# 21   27   15000.000000
# 22   28   28333.333333
# 23   29   17500.000000
# 24   31  150000.000000
# 25   33  130000.000000
# 26   35    6000.000000
# 27   38   20000.000000

# %%
import matplotlib.pyplot as plt

depreciation.plot(kind='line',
                  marker='o',
                  figsize=(10,5))

plt.xlabel('Bike Age')
plt.ylabel('Average Selling Price')
plt.title('Average Depreciation by Bike Age')

plt.show()

# %% [markdown]
# # 15 Develop a correlation matrix for numeric columns and visualize it using a heatmap.

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_df.corr()

plt.figure()
sns.heatmap( corr_matrix,
            annot=True,
            cmap='coolwarm',
            fmt='.2f')
plt.title('Correlation Matrix Heatmap')

plt.show()
